# %%
import pandas as pd
import numpy as np
import pylab as plt
import matplotlib.pyplot as plt
##import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from scipy.stats import skew
import numpy as np
import seaborn as sns
from scipy import stats
color = sns.color_palette()
from sklearn import model_selection, preprocessing
import datetime
import scipy as sp
# Get ready for lots of annoying deprecation warnings
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn_pandas import DataFrameMapper
# %matplotlib inline

# %%
def clean_data_macro(df):
    # convert object column to numeric
    char_columns = (df.dtypes[df.dtypes.map(lambda x : x =='object')]).index
    float_columns = (df.dtypes[df.dtypes.map(lambda x : x =='float64')]).index
    le=LabelEncoder()
    for feature in char_columns:
        df[feature]=le.fit_transform(df[feature])
    # cvert float64 to float32
    df[float_columns]=df[float_columns].astype(np.float32)
    df.fillna(df.median(),inplace = True)
    return df

# %% [markdown]
# ### Summary Clean for train set

# %%
# drop missing value >0.35 of total observations
# keep state and build_year for training data
def drop_high_volumn_missing(df):
    not_move = ["build_year","state"]
    high_missing_train_feature= df.columns[df.isnull().sum()>0.35*len(df)].tolist()
    
    for g in not_move:
        if g in high_missing_train_feature:
            high_missing_train_feature.remove(g)
    df.drop(high_missing_train_feature,axis = 1, inplace=True)    
    return df

## drop build_ columns: drop na obs or drop columns
def drop_build_function(df):
    not_move = ["build_year"]
    build_feature = df.filter(regex=r'^build_count_', axis=1).columns.tolist()
    build_feature2 = df.filter(regex=r'^raion_build_count_', axis=1).columns.tolist()
    for e in build_feature:
        for g in not_move:
            if e==g:
                high_missing_train_feature.remove(e)
    build_feature.extend(build_feature2)
    df.drop(build_feature,axis = 1)
    return df

# remove outliers
'''def reject_outliers(df, m = 1):
    d = np.abs(df - np.median(df))
    mdev = np.median(d)
    s = d/mdev if mdev else 0.
    return df[s<m]
'''
def reject_outliers(df, iq_range=0.5):
    #df[np.abs(df.Data-df.Data.mean())<=(3*df.Data.std())]
    pcnt = (1 - iq_range) / 2
    qlow, median, qhigh = df.dropna().quantile([pcnt, 0.50, 1-pcnt])
    iqr = qhigh - qlow
    return df[ (df - median).abs() <= iqr]

def clean_data(df):
    #add str feature 
    #df_all.apartment_name=df_all.sub_area + df_all['metro_km_avto'].astype(str)

    # convert object column to numeric
    char_columns = (df.dtypes[df.dtypes.map(lambda x : x =='object')]).index
    float_columns = (df.dtypes[df.dtypes.map(lambda x : x =='float64')]).index
    le=LabelEncoder()
    for feature in char_columns:
        df[feature]=le.fit_transform(df[feature])
    # cvert float64 to float32
    df[float_columns]=df[float_columns].astype(np.float32)
    
    # fill build_ and cafe_, state, NA to 0

    df.filter(regex=r'^cafe_', axis=1).fillna(0, inplace=True)
    #build_feature
    not_move = ["build_year"]
    build_feature = df.filter(regex=r'^build_count_', axis=1).columns.tolist()
    build_feature2 = df.filter(regex=r'^raion_build_count_', axis=1).columns.tolist()
    for e in build_feature:
        for g in not_move:
            if e==g:
                high_missing_train_feature.remove(e)
    build_feature.extend(build_feature2)
    #build fill median or 0?
    df[build_feature].fillna(df[build_feature].median(),inplace=True)
    #fill state
    df['state'].fillna(0,inplace=True) 
    df.fillna(df.median(), inplace = True)
    return df

# %%
# add month year week and other feature
def add_feature(df_all):
    month_year = (df_all.timestamp.dt.month + df_all.timestamp.dt.year * 100)
    month_year_cnt_map = month_year.value_counts().to_dict()
    df_all['month_year_cnt'] = month_year.map(month_year_cnt_map)

    week_year = (df_all.timestamp.dt.weekofyear + df_all.timestamp.dt.year * 100)
    week_year_cnt_map = week_year.value_counts().to_dict()
    df_all['week_year_cnt'] = week_year.map(week_year_cnt_map)

    df_all['month'] = df_all.timestamp.dt.month
    df_all['dow'] = df_all.timestamp.dt.dayofweek

    # Other feature engineering
    df_all['rel_floor'] = df_all['floor'] / df_all['max_floor'].astype(float)
    df_all['rel_kitch_sq'] = df_all['kitch_sq'] / df_all['full_sq'].astype(float)
    
    df_all['rel_kitch_sq'].fillna(0,inplace=True)
    df_all['rel_floor'].fillna(0,inplace=True)
    
    df_all['room_size'] = df_all['life_sq'] / df_all['num_room'].astype(float)
   # df_all.replace(np.inf, np.nan)
    ##trainBuild = df_train.dropna()
     #3* Polynomials on the top 1 existing features
    df_all["full_sq-s2"] = df_all["full_sq"] ** 2
    df_all["full_sq-s3"] = df_all["full_sq"] ** 3
    df_all["full_sq-Sq"] = np.sqrt(df_all["full_sq"])
    df_all["yearbuilt"] = pd.to_numeric(df_all["build_year"].map(lambda x:str(x).split(".")[0]),errors='coerce')
    # Remove timestamp buildyear column (may overfit the model in train)
    df_all.drop(['timestamp',"id"], axis=1, inplace=True)
    return df_all

# %%
#load files
train = pd.read_csv('./data/output/train_clean.csv', parse_dates=['timestamp'])
test = pd.read_csv('./data/output/test_clean.csv', parse_dates=['timestamp'])
macro_cols = ["balance_trade", "balance_trade_growth", "eurrub", "average_provision_of_build_contract",
"micex_rgbi_tr", "micex_cbi_tr", "deposits_rate", "mortgage_value", "mortgage_rate",
"income_per_cap", "rent_price_4+room_bus", "museum_visitis_per_100_cap", "apartment_build"]
macro = pd.read_csv('./data/input/macro.csv',parse_dates=['timestamp'],
                   usecols=['timestamp']+macro_cols)
macros = clean_data_macro(macro) #clean macros

#id_test = test.id

# %%
# Find most important features relative to target
print("Find most important features relative to target")
corr = train.corr()
corr.sort_values(["price_doc"], ascending = False, inplace = True)
print(corr.price_doc)
# Out:
# Find most important features relative to target
# price_doc                     1.000000
# full_sq                       0.616516
# num_room                      0.490692
# life_sq                       0.484116
# kitch_sq                      0.354887
# sport_count_5000              0.297394
# sport_count_3000              0.292979
# trc_count_5000                0.291207
# sport_count_2000              0.280532
# office_sqm_5000               0.272362
# trc_sqm_5000                  0.269786
# sport_count_1500              0.260777
# sport_objects_raion           0.255460
# trc_count_3000                0.244037
# cafe_count_5000_price_1000    0.242608
# cafe_count_5000_price_1500    0.234759
# cafe_count_5000               0.233667
# cafe_count_5000_na_price      0.232171
# office_sqm_3000               0.229115
# cafe_count_5000_price_500     0.229006
# cafe_count_5000_price_2500    0.227656
# trc_sqm_3000                  0.227451
# office_count_5000             0.221321
# office_sqm_2000               0.218604
# cafe_count_5000_price_high    0.216587
# church_count_5000             0.215166
# cafe_count_5000_price_4000    0.212475
# leisure_count_5000            0.202340
# big_church_count_5000         0.200722
# sport_count_1000              0.200168
#                                 ...
# area_m                       -0.168745
# public_healthcare_km         -0.175718
# market_shop_km               -0.176520
# shopping_centers_km          -0.179703
# metro_km_avto                -0.180590
# metro_km_walk                -0.184011
# metro_min_walk               -0.184011
# park_km                      -0.187633
# fitness_km                   -0.192657
# metro_min_avto               -0.193446
# radiation_km                 -0.193791
# big_church_km                -0.195145
# museum_km                    -0.198468
# exhibition_km                -0.209233
# workplaces_km                -0.211104
# thermal_power_plant_km       -0.211585
# catering_km                  -0.212431
# swim_pool_km                 -0.213320
# theater_km                   -0.217582
# university_km                -0.220146
# basketball_km                -0.224845
# office_km                    -0.225174
# detention_facility_km        -0.225872
# stadium_km                   -0.238086
# nuclear_reactor_km           -0.259726
# ttk_km                       -0.274754
# bulvar_ring_km               -0.281345
# kremlin_km                   -0.281400
# sadovoe_km                   -0.285816
# zd_vokzaly_avto_km           -0.286216
# Name: price_doc, Length: 276, dtype: float64

# %%
categorical_features = train.select_dtypes(include = ["object"]).columns
numerical_features = train.select_dtypes(exclude = ["object"]).columns
numerical_features = numerical_features.drop(["price_doc", 'id',"timestamp"])
print("Numerical features : " + str(len(numerical_features)))
print("Categorical features : " + str(len(categorical_features)))
train_num = train[numerical_features]
train_cat = train[categorical_features]
# Out:
# Numerical features : 274
# Categorical features : 15

# %%
# Log transform of the skewed numerical features to lessen impact of outliers
# Inspired by Alexandru Papiu's script : https://www.kaggle.com/apapiu/house-prices-advanced-regression-techniques/regularized-linear-models
# As a general rule of thumb, a skewness with an absolute value > 0.5 is considered at least moderately skewed

skewness = train_num.apply(lambda x: skew(x))
skewness = skewness[abs(skewness) > 0.8]
print(str(skewness.shape[0]) + " skewed numerical features to log transform")
skewed_features = skewness.index
train[skewed_features] = np.log1p(train[skewed_features])
# Out:
# 204 skewed numerical features to log transform

# %%
df_train = clean_data(train)
df_train.fillna(df_train.median(),inplace = True)
df_train.shape
# Out:
# (30396, 292)

# %%
df_test = clean_data(test)
df_test.fillna(df_test.median(),inplace = True)
df_test.shape
# Out:
# (7662, 291)

# %%
df_train = pd.merge_ordered(df_train, macros, on='timestamp', how='left')
df_train.shape
# Out:
# (30396, 305)

# %%
df_test = pd.merge_ordered(df_test, macros, on='timestamp', how='left')
df_test.shape
# Out:
# (7662, 304)

# %%
dtrain=add_feature(df_train)
print dtrain.shape
dtest=add_feature(df_test)
dtest.shape
# Out:
# (30396, 314)
# (7662, 313)

# %%
xtrain = clean_data_macro(dtrain)
xtest=clean_data_macro(dtest)
print xtrain.shape
print xtest.shape
# Out:
# (30396, 314)
# (7662, 313)

# %%
#train low correlated feature or VIF 
#train_feature = pd.read_csv("./data/output/train_feature_multicoliear.csv")
train_feature = pd.read_csv("./data/output/train_corr_drop.csv")# to drop
train_feature.shape
# Out:
# (30471, 142)

# %%
#readin train set
#df_train = pd.read_csv("./data/input/train.csv",parse_dates=['timestamp'],
                      #usecols =['timestamp','price_doc','build_year']+train_feature.columns.tolist())
#df_train = pd.read_csv("./data/input/train.csv",parse_dates=['timestamp'])
feature_drop = train_feature.columns.tolist()+["price_doc"]
y_train =np.log1p(xtrain["price_doc"])
x_train=xtrain.drop(feature_drop, axis = 1)
x_train.shape
# Out:
# (30396, 171)

# %%
dtype_df = x_train.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
dtype_df.groupby("Column Type").aggregate('count').reset_index()
# Out:
#   Column Type  Count
# 0     float32    151
# 1       int64     20

# %%
#feature_drop.remove("price_doc")
feature_drop = train_feature.columns.tolist()
x_test = xtest.drop(feature_drop, axis = 1)
x_test.shape
# Out:
# (7662, 171)

# %%
#scale and center for ridge & lasso
X_scaler = StandardScaler()
x_train_feature = X_scaler.fit_transform(x_train)
x_test_feature = X_scaler.transform(x_test)

# %% [markdown]
# Standardization cannot be done before the partitioning, as we don't want to fit the StandardScaler on some observations that will later be used in the test set.

# %%
x_train_scale= pd.DataFrame(x_train_feature, index=x_train.index, columns=x_train.columns)
x_train_scale.head()
# Out:
#     full_sq   life_sq     floor  max_floor  material  build_year  num_room  \
# 0 -0.509124 -0.398877 -0.693639     0.0695 -0.441666   -0.005756  0.090872
# 1 -0.928870 -0.893301 -0.882798     0.0695 -0.441666   -0.005756  0.090872
# 2 -0.509124 -0.275271 -1.071957     0.0695 -0.441666   -0.005756  0.090872
# 3  1.636249  1.022593  0.252156     0.0695 -0.441666   -0.005756  0.090872
# 4  1.076587  2.691274 -0.693639     0.0695 -0.441666   -0.005756  0.090872
#
#    kitch_sq    state  sub_area    ...      museum_visitis_per_100_cap  \
# 0 -0.004263 -0.95677 -1.718994    ...                       -1.705883
# 1 -0.004263 -0.95677 -0.165284    ...                       -1.705883
# 2 -0.004263 -0.95677  1.337486    ...                       -1.705883
# 3 -0.004263 -0.95677 -0.292637    ...                       -1.705883
# 4 -0.004263 -0.95677 -1.795406    ...                       -1.705883
#
#    apartment_build  month_year_cnt  week_year_cnt     month       dow  \
# 0        -5.681733       -2.284752      -1.888030  0.355458  1.780819
# 1        -5.681733       -2.284752      -1.878993  0.355458 -0.758310
# 2        -5.681733       -2.284752      -1.878993  0.355458  1.780819
# 3        -5.681733       -2.188680      -1.888030  0.639705  0.511255
# 4        -5.681733       -2.188680      -1.851884  0.639705 -1.393092
#
#    rel_floor  rel_kitch_sq  room_size  yearbuilt
# 0  -0.869131      0.403689  -0.560230  -0.005756
# 1  -1.086592      1.277864  -1.020777  -0.005756
# 2  -1.304054      0.403689  -0.445094  -0.005756
# 3   0.218175     -1.303190   0.763841  -0.005756
# 4  -0.869131     -1.054532   2.318186  -0.005756
#
# [5 rows x 168 columns]

# %%
x_test_scale= pd.DataFrame(x_test_feature, index=x_test.index, columns=x_test.columns)
x_test_scale.head()
# Out:
#     full_sq   life_sq     floor  max_floor  material  build_year  num_room  \
# 0 -0.695678 -0.788236 -1.071957  -0.951830 -0.441666   -0.005609 -1.360595
# 1  1.179191 -0.176386  0.062997   0.682298 -0.441666   -0.005713  1.542339
# 2 -0.625720 -0.516303 -0.882798  -1.768894  0.335956   -0.005939  0.090872
# 3  0.414319  0.157350  1.765428   0.682298 -0.441666   -0.005452  0.090872
# 4 -0.649039  0.404562  1.765428   0.682298 -0.441666   -0.005713 -1.360595
#
#    kitch_sq     state  sub_area    ...      museum_visitis_per_100_cap  \
# 0  0.434147  1.497405 -0.980345    ...                       -0.547941
# 1  0.239298 -0.138711  0.649778    ...                       -0.547941
# 2 -1.563053  0.679347  0.191306    ...                       -0.547941
# 3  0.239298  1.497405  0.700719    ...                       -0.547941
# 4  0.239298 -0.138711  0.649778    ...                       -0.547941
#
#    apartment_build  month_year_cnt  week_year_cnt     month       dow  \
# 0        -0.569462       -1.235965      -1.363919  0.071211 -0.123527
# 1        -0.569462       -1.235965      -1.363919  0.071211 -0.123527
# 2        -0.569462       -1.235965      -1.363919  0.071211 -0.123527
# 3        -0.569462       -1.235965      -1.363919  0.071211 -0.123527
# 4        -0.569462       -1.235965      -1.363919  0.071211 -0.123527
#
#    rel_floor  rel_kitch_sq  room_size  yearbuilt
# 0  -1.062430      1.152030   0.268754  -0.005609
# 1  -0.306290     -0.993698  -0.940181  -0.005713
# 2   0.087698     -0.794975  -0.669610  -0.005939
# 3   1.305481     -0.496200  -0.042115  -0.005452
# 4   1.305481      0.873255   2.490891  -0.005713
#
# [5 rows x 168 columns]

# %%
'''mapper = DataFrameMapper([(x_train.columns, StandardScaler())])
scaled_features = mapper.fit_transform(x_train.copy())
scaled_features_df = pd.DataFrame(scaled_features, index=x_train.index, columns=x_train.columns)
scaled_features_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-f9ca0bcab001> in <module>()
# ----> 1 mapper = DataFrameMapper([(x_train.columns, StandardScaler())])
#       2 scaled_features = mapper.fit_transform(x_train.copy())
#       3 scaled_features_df = pd.DataFrame(scaled_features, index=x_train.index, columns=x_train.columns)
#       4 scaled_features_df.head()
#
# NameError: name 'DataFrameMapper' is not defined

# %%
# Remove near zero variance features

def get_low_variance_columns(dframe=None, columns=None,
                             skip_columns=None, thresh=0.0,
                             autoremove=False):
    """
    Wrapper for sklearn VarianceThreshold for use on pandas dataframes.
    """
    print("Finding low-variance features.")
    try:
        # get list of all the original df columns
        all_columns = dframe.columns

        # remove `skip_columns`
        remaining_columns = all_columns.drop(skip_columns)

        # get length of new index
        max_index = len(remaining_columns) - 1

        # get indices for `skip_columns`
        skipped_idx = [all_columns.get_loc(column)
                       for column
                       in skip_columns]

        # adjust insert location by the number of columns removed
        # (for non-zero insertion locations) to keep relative
        # locations intact
        for idx, item in enumerate(skipped_idx):
            if item > max_index:
                diff = item - max_index
                skipped_idx[idx] -= diff
            if item == max_index:
                diff = item - len(skip_columns)
                skipped_idx[idx] -= diff
            if idx == 0:
                skipped_idx[idx] = item

        # get values of `skip_columns`
        skipped_values = dframe.iloc[:, skipped_idx].values

        # get dataframe values
        X = dframe.loc[:, remaining_columns].values

        # instantiate VarianceThreshold object
        vt = VarianceThreshold(threshold=thresh)

        # fit vt to data
        vt.fit(X)

        # get the indices of the features that are being kept
        feature_indices = vt.get_support(indices=True)

        # remove low-variance columns from index
        feature_names = [remaining_columns[idx]
                         for idx, _
                         in enumerate(remaining_columns)
                         if idx
                         in feature_indices]

        # get the columns to be removed
        
        removed_features = list(np.setdiff1d(remaining_columns,
                                             feature_names))
        print("Found {0} low-variance columns."
              .format(len(removed_features)))

        # remove the columns
        if autoremove:
            print("Removing low-variance features.")
            # remove the low-variance columns
            X_removed = vt.transform(X)

            print("Reassembling the dataframe (with low-variance "
                  "features removed).")
            # re-assemble the dataframe
            dframe = pd.DataFrame(data=X_removed,
                                  columns=feature_names)

            # add back the `skip_columns`
            for idx, index in enumerate(skipped_idx):
                dframe.insert(loc=index,
                              column=skip_columns[idx],
                              value=skipped_values[:, idx])
            print("Succesfully removed low-variance columns.")

        # do not remove columns
        else:
            print("No changes have been made to the dataframe.")

    except Exception as e:
        print(e)
        print("Could not remove low-variance features. Something "
              "went wrong.")
        pass

    return dframe

# %%
get_low_variance_columns(dframe=x_train_scale, columns=None,
                             skip_columns=None, thresh=0.1,
                             autoremove=False)
# Out:
# Finding low-variance features.
# labels [None] not contained in axis
# Could not remove low-variance features. Something went wrong.
#         full_sq   life_sq     floor  max_floor  material  build_year  \
# 0     -0.509124 -0.398877 -0.693639   0.069500 -0.441666   -0.005756
# 1     -0.928870 -0.893301 -0.882798   0.069500 -0.441666   -0.005756
# 2     -0.509124 -0.275271 -1.071957   0.069500 -0.441666   -0.005756
# 3      1.636249  1.022593  0.252156   0.069500 -0.441666   -0.005756
# 4      1.076587  2.691274 -0.693639   0.069500 -0.441666   -0.005756
# 5      0.610201  0.775380  1.197951   0.069500 -0.441666   -0.005756
# 6     -1.348617 -1.202317  0.441315   0.069500 -0.441666   -0.005756
# 7     -0.462485  0.651774 -0.504480   0.069500 -0.441666   -0.005756
# 8     -0.555762 -0.398877 -0.504480   0.069500 -0.441666   -0.005756
# 9     -0.835593 -0.769695  0.252156   0.069500 -0.441666   -0.005756
# 10    -0.835593 -0.893301  0.819633   0.069500 -0.441666   -0.005756
# 11    -0.742316 -0.893301  0.630474   0.069500 -0.441666   -0.005756
# 12    -0.509124 -0.337074 -0.693639   0.069500 -0.441666   -0.005756
# 13    -1.068786 -0.151665 -0.693639   0.069500 -0.441666   -0.005756
# 14    -1.068786 -0.769695 -0.882798   0.069500 -0.441666   -0.005756
# 15    -0.136015 -0.151665  1.387110   0.069500 -0.441666   -0.005756
# 16    -0.322569 -0.151665 -0.693639   0.069500 -0.441666   -0.005756
# 13     -0.005756
# 14     -0.005756
# 15     -0.005756
# 16     -0.005756
# 17     -0.005756
# 18     -0.005756
# 19     -0.005756
# 20     -0.005756
# 21     -0.005756
# 22     -0.005756
# 23     -0.005756
# 24     -0.005756
# 25     -0.005756
# 26     -0.005756
# 27     -0.005756
# 28     -0.005756
# 29     -0.005756
# ...          ...
# 30366  -0.005461
# 30367  -0.005461
# 30368  -0.005756
# 30369  -0.005452
# 30370  -0.005452
# 30371  -0.005443
# 30372  -0.005756
# 30373  -0.005756
# 30374  -0.005461
# 30375  -0.005756
# 30376  -0.005756
# 30377  -0.005539
# 30378  -0.005461
# 30379  -0.005835
# 30380  -0.005756
# 30381  -0.005661
# 30382  -0.005774
# 30383  -0.005461
# 30384  -0.005756
# 30385  -0.005774
# 30386  -0.005765
# 30387  -0.005452
# 30388  -0.005583
# 30389  -0.005443
# 30390  -0.005756
# 30391  -0.005809
# 30392  -0.006156
# 30393  -0.005756
# 30394  -0.005565
# 30395  -0.005870
#
# [30396 rows x 168 columns]

# %% [markdown]
# ### Ridge & Lasso

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from sklearn import cross_validation
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import cross_val_score, train_test_split

# %%
# Define error measure for official scoring : RMSE
scorer = make_scorer(mean_squared_error, greater_is_better = False)

def rmse_cv_train(model):
    rmse= np.sqrt(-cross_val_score(model, train_x, train_y, scoring = scorer, cv = 10))
    return(rmse)

def rmse_cv_test(model):
    rmse= np.sqrt(-cross_val_score(model, test_x, test_y, scoring = scorer, cv = 10))
    return(rmse)

# %%
alphas = 10**np.linspace(10,-2,100)*0.5

# %%
ridge = Ridge(normalize=True)
coefs = []
for a in alphas:
    ridge.set_params(alpha=a)
    ridge.fit(x_train, y_train)
    coefs.append(ridge.coef_)
np.shape(coefs)
# Out:
# (100, 171)

# %%
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')

# %%
train_x, test_x, train_y, test_y = cross_validation.train_test_split(x_train, y_train, test_size=0.5, random_state=1)

# %%
ridge2 = Ridge(alpha=4, normalize=True)
ridge2.fit(train_x, train_y)
# Fit a ridge regression on the training data
pred2 = ridge2.predict(test_x)
# Use this model to predict the test data
print(pd.Series(ridge2.coef_, index=x_train.columns))
# Print coefficients
print(mean_squared_error(test_y, pred2))
# Calculate the test MSE
# Out:
# full_sq                                  9.919165e-02
# life_sq                                  1.295120e-03
# floor                                    1.845073e-03
# max_floor                                1.869430e-03
# material                                 1.229941e-03
# build_year                               3.411431e-09
# num_room                                 2.945012e-02
# kitch_sq                                 5.650685e-03
# state                                    4.754969e-03
# sub_area                                -9.736844e-05
# area_m                                  -1.994952e-03
# indust_part                             -6.892880e-02
# preschool_quota                         -9.730115e-07
# children_school                          1.814653e-03
# school_quota                             1.494233e-07
# school_education_centers_raion           1.668060e-03
# school_education_centers_top_20_raion   -1.280945e-03
# hospital_beds_raion                      4.232493e-06
# healthcare_centers_raion                 5.958502e-03
# university_top_20_raion                  2.095570e-03
# sport_objects_raion                      3.964153e-03
# additional_education_raion              -9.833274e-04
# culture_objects_top_25_raion            -1.021529e-02
# shopping_centers_raion                   2.663831e-03
# office_raion                             2.351252e-03
# thermal_power_plant_raion               -3.162366e-03
# incineration_raion                       5.767642e-04
# oil_chemistry_raion                     -2.411072e-02
# radiation_raion                         -6.981467e-03
# railroad_terminal_raion                 -1.874321e-02
#                                              ...
# trc_sqm_5000                             1.224312e-03
# cafe_count_5000_price_high               9.488867e-03
# mosque_count_5000                        1.269897e-02
# leisure_count_5000                       3.092048e-03
# sport_count_5000                         4.410662e-03
# market_count_5000                        2.974603e-04
# balance_trade                           -1.868760e-04
# balance_trade_growth                     1.910450e-04
# eurrub                                   7.352045e-04
# average_provision_of_build_contract      3.078468e-02
# micex_rgbi_tr                           -6.874024e-04
# micex_cbi_tr                             6.627408e-04
# deposits_rate                            2.359376e-03
# mortgage_value                           3.301565e-09
# mortgage_rate                            8.755194e-03
# income_per_cap                           1.771949e-07
# rent_price_4+room_bus                    2.155677e-04
# museum_visitis_per_100_cap              -4.279150e-06
# apartment_build                          1.746289e-06
# month_year_cnt                           1.530160e-05
# week_year_cnt                            4.254871e-05
# month                                   -3.702623e-04
# dow                                     -4.337068e-04
# rel_floor                                1.544428e-02
# rel_kitch_sq                             5.492345e-04
# room_size                                5.456375e-04
# full_sq-s2                               1.233758e-02
# full_sq-s3                               2.009615e-03
# full_sq-Sq                               3.951813e-01
# yearbuilt                                3.411431e-09
# Length: 171, dtype: float64
# 0.236955524093

# %%
ridge3 = Ridge(alpha=10**10, normalize=True)
ridge3.fit(train_x, train_y)
# Fit a ridge regression on the training data
pred3 = ridge3.predict(test_x)
# Use this model to predict the test data
print(pd.Series(ridge3.coef_, index=x_train.columns))
# Print coefficients
print(mean_squared_error(test_y, pred3))
# Calculate the test MSE
# Out:
# full_sq                                  1.356908e-12
# life_sq                                  1.291450e-12
# floor                                    1.439579e-12
# max_floor                                1.258937e-12
# material                                 2.313466e-12
# build_year                               2.002752e-18
# num_room                                 3.083828e-11
# kitch_sq                                 5.030909e-12
# state                                    6.896931e-12
# sub_area                                -1.126994e-13
# area_m                                  -4.598328e-19
# indust_part                             -3.482245e-11
# preschool_quota                         -8.615858e-16
# children_school                          1.937438e-15
# school_quota                             2.677025e-16
# school_education_centers_raion           3.029825e-12
# school_education_centers_top_20_raion    1.369469e-11
# hospital_beds_raion                      6.915106e-15
# healthcare_centers_raion                 6.516458e-12
# university_top_20_raion                  1.544018e-11
# sport_objects_raion                      1.833415e-12
# additional_education_raion               1.131293e-12
# culture_objects_top_25_raion             9.457486e-13
# shopping_centers_raion                   1.747443e-12
# office_raion                             2.515951e-13
# thermal_power_plant_raion                4.283578e-12
# incineration_raion                      -1.110612e-11
# oil_chemistry_raion                     -1.530466e-11
# radiation_raion                          9.101226e-12
# railroad_terminal_raion                  1.736037e-11
#                                              ...
# sport_count_3000                         7.270030e-13
# prom_part_5000                           9.731240e-13
# office_count_5000                        6.325824e-14
# trc_sqm_5000                             1.300464e-17
# cafe_count_5000_price_high               1.720105e-12
# mosque_count_5000                        1.388914e-11
# leisure_count_5000                       4.255516e-13
# sport_count_5000                         3.021803e-13
# market_count_5000                        2.112880e-12
# balance_trade                            6.069527e-15
# balance_trade_growth                     2.359627e-13
# eurrub                                   7.860904e-13
# average_provision_of_build_contract      3.039634e-11
# micex_rgbi_tr                           -8.103918e-13
# micex_cbi_tr                             5.364020e-13
# deposits_rate                            2.548300e-12
# mortgage_value                           4.466659e-18
# mortgage_rate                            6.903967e-12
# income_per_cap                           1.621888e-16
# rent_price_4+room_bus                    2.342154e-13
# museum_visitis_per_100_cap              -3.233147e-14
# apartment_build                          1.060071e-15
# month_year_cnt                           1.383597e-14
# week_year_cnt                            4.219011e-14
# month                                   -3.154962e-13
# dow                                     -1.296504e-13
# rel_floor                                1.444293e-11
# rel_kitch_sq                            -4.008310e-10
# room_size                                3.958623e-13
# yearbuilt                                2.002752e-18
# dtype: float64
# 0.350679751042

# %%
ridgecv = RidgeCV(alphas=alphas, scoring='neg_mean_squared_error', normalize=True)
ridgecv.fit(train_x, train_y)
alpha = ridgecv.alpha_
print("Best alpha :", alpha)
# Out:
# ('Best alpha :', 0.0050000000000000001)

# %%
ridgecv = RidgeCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                          alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                          alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], 
                cv = 10)
ridgecv.fit(train_x, train_y)
alpha = ridgecv.alpha_
print("Best alpha :", alpha)
# Out:
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.12622211895e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.80894271382e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.59977491139e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.05143082158e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.72564785844e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.64780426947e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368882e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.0768176303e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340308e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.78237027569e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.45399077224e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.59977491138e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.78805460736e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.27160236361e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.3001768027e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368883e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.04092370929e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.33261608369e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.12622211891e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.94521922563e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.05143082155e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.90809098994e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.64780426952e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368885e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.11271155131e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.6105134031e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.12622211886e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.45399077212e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.94521922557e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.78805460737e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.08915923227e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.64780426954e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.18449939333e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340324e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.12622211894e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.09903883063e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.29066353985e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.05143082165e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.99862511111e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.6478042694e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.28648887174e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.6105134032e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.80894271401e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.6361078541e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.05143082167e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.54457961626e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.99543173638e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.87675850596e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.14860547233e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340321e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.45399077235e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.25433059741e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.78805460743e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.72564785874e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.11271155132e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340322e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.7823702757e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.09903883094e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.94521922571e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.05143082166e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.27160236375e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.34305920322e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368886e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340316e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.51884659702e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.29066353993e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.41974271452e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.63511373748e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.99543173646e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368884e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.0409237093e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.12622211896e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.16389465561e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.94521922578e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.78805460754e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.27160236376e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.64780426966e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.12622211893e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.45399077253e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.29066354002e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.31480703592e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.2716023638e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.99543173647e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 5.28648887172e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.33261608391e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.16389465563e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.29066353994e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.54457961629e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 9.03831413688e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.87675850591e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340326e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.09903883097e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.2543305975e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.27160236378e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.30017680279e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340331e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.80894271409e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.94521922589e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.05143082172e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.90809099007e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 6.95254933598e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368888e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 1.14860547234e-17
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.61051340328e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.78237027572e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.45399077242e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.94521922592e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.78805460742e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 3.27160236385e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.30017680294e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368887e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.33261608386e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.09903883098e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.9452192258e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.78805460744e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.54457961633e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 7.30017680293e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 4.58162368881e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# ('Best alpha :', 0.0030000000000000001)
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/scipy/linalg/basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 2.46609470095e-18
#   ' condition number: {}'.format(rcond), RuntimeWarning)

# %%
ridge4 = Ridge(alpha=ridgecv.alpha_, normalize=True)
ridge4.fit(train_x, train_y)
mean_squared_error(test_y, ridge4.predict(test_x))
# Out:
# 0.2106397354520971

# %%
print("Ridge RMSE on Training set :", rmse_cv_train(ridge4).mean())
print("Ridge RMSE on Test set :", rmse_cv_test(ridge4).mean())
y_train_rdg = ridge4.predict(train_x)
y_test_rdg = ridge4.predict(test_x)
# Out:
# ('Ridge RMSE on Training set :', 6.0763592093605503)
# ('Ridge RMSE on Test set :', 0.45932722649013363)

# %%
cv_score_vl = cross_validation.cross_val_score(ridge4, test_x, test_y)
print cv_score_vl
# Out:
# [ 0.40400706  0.38679006  0.39187145]

# %%
# Plot residuals
plt.scatter(y_train_rdg, y_train_rdg - train_y, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, y_test_rdg - test_y, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 12, xmax = 20, color = "red")
plt.show()

# Plot predictions
plt.scatter(y_train_rdg, train_y, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, test_y, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([12, 20], [12, 20], c = "red")
plt.show()

# Plot important coefficients
coefs = pd.Series(ridge.coef_, index = train_x.columns)
print("Ridge picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Ridge Model")
plt.show()
# Out:
# Ridge picked 171 features and eliminated the other 0 features

# %% [markdown]
# ### Lasso

# %%
lasso = Lasso(max_iter=10000, normalize=True)
coefs = []
for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(scale(train_x), train_y)
    coefs.append(lasso.coef_)
ax = plt.gca()
ax.plot(alphas*2, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')

# %%
lassocv = LassoCV(alphas=None, cv=10, max_iter=100000, normalize=True)
lassocv.fit(train_x, train_y)
lasso.set_params(alpha=lassocv.alpha_)
lasso.fit(train_x, train_y)
mean_squared_error(test_y, lasso.predict(test_x))
# Out:
# 0.21129413497691621

# %%
print("Ridge RMSE on Training set :", rmse_cv_train(lasso).mean())
print("Ridge RMSE on Test set :", rmse_cv_test(lasso).mean())
y_train_rdg = lasso.predict(train_x)
y_test_rdg = lasso.predict(test_x)
# Out:
# ('Ridge RMSE on Training set :', 0.46734021781122453)
# ('Ridge RMSE on Test set :', 0.46003295742703915)

# %%
# Plot residuals
plt.scatter(y_train_rdg, y_train_rdg - train_y, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, y_test_rdg - test_y, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Ridge regularization")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.legend(loc = "upper left")
plt.hlines(y = 0, xmin = 12, xmax = 20, color = "red")
plt.show()

# Plot predictions
plt.scatter(y_train_rdg, train_y, c = "blue", marker = "s", label = "Training data")
plt.scatter(y_test_rdg, test_y, c = "lightgreen", marker = "s", label = "Validation data")
plt.title("Linear regression with Lasso regularization")
plt.xlabel("Predicted values")
plt.ylabel("Real values")
plt.legend(loc = "upper left")
plt.plot([12, 20], [12, 20], c = "red")
plt.show()

# Plot important coefficients
coefs = pd.Series(lasso.coef_, index = train_x.columns)
print("Lasso picked " + str(sum(coefs != 0)) + " features and eliminated the other " +  \
      str(sum(coefs == 0)) + " features")
imp_coefs = pd.concat([coefs.sort_values().head(10),
                     coefs.sort_values().tail(10)])
imp_coefs.plot(kind = "barh")
plt.title("Coefficients in the Ridge Model")
plt.show()
# Out:
# Lasso picked 89 features and eliminated the other 82 features

# %%
cv_score_lasso = cross_validation.cross_val_score(lasso, test_x, test_y)
print cv_score_lasso
# Out:
# [ 0.40549555  0.38922401  0.39124332]

# %% [markdown]
# ### submission for linear

# %%
df_test = pd.read_csv("./data/input/test.csv", usecols =['id'])

y_predict = lasso.predict(x_test)
p_y =np.exp(y_predict)-1
id_test = df_test.id
lasso_output = pd.DataFrame({'id': id_test, 'price_doc': p_y})
lasso_output.head()
# Out:
# /Users/whalejasmine/anaconda/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.
#       id  price_doc
# 0  30474  -1.000000
# 1  30475        inf
# 2  30476        inf
# 3  30477  -1.000000
# 4  30478  -1.000000

# %%
lasso_output.to_csv('./data/output/lasso.csv', index=False)
